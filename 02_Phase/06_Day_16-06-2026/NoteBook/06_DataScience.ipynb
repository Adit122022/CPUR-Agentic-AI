# %% [markdown]
# # 🔬 Data Science — Introduction & Lifecycle
# ### 📅 Day 6 | CPUR Agentic AI Internship | 16 June 2026
#
# > **Data Science** is the process of converting **raw data** into **meaningful information** and **actionable insights**.
#
# ---

# %% [markdown]
# ## 🔄 Lifecycle of Data Science
#
# A Data Science project follows a step-by-step process called **the Data Science Lifecycle**.
#
# ```
# 1. Problem Understanding
# 2. Data Collection
# 3. Data Cleaning
# 4. Data Analysis (EDA)
# 5. Data Visualization
# 6. Model Building
# 7. Model Evaluation
# 8. Deployment
# 9. Monitoring & Improvement
# ```

# %% [markdown]
# ## 1️⃣ Problem Understanding
#
# Before collecting data, we must understand the problem.
#
# **Questions to Ask:**
# - What is the business problem?
# - What is the objective?
# - What is the expected outcome?
# - How will success be measured?
#
# **Example:**
# ```
# Business Problem : Sales are decreasing.
# Question         : Why are customers leaving?
# Goal             : Identify customers likely to leave and take action.
# ```
#
# > ⚠️ Without understanding the problem, even the best data and models are useless.

# %% [markdown]
# ## 2️⃣ Data Collection
#
# Once the problem is clear, the next step is collecting relevant data.
#
# **Data Sources:**
# 1. Databases
# 2. Company ERP Systems
# 3. Websites
# 4. APIs
# 5. Sensors & IoT Devices
# 6. Social Media
# 7. Excel / CSV Files
#
# **Example — Customer Churn Prediction, collect:**
# - Customer Name, Age, Purchase History
# - Last Purchase Date, Total Spending, Customer Feedback
#
# **Data Engineer Role:**
# ```
# Tasks  : Build Pipelines, Data Warehouses, Manage Databases, Handle Big Data
# Tools  : Python, SQL, Spark, Kafka, AWS
# ```

# %% [markdown]
# ## 3️⃣ Data Cleaning
#
# Real-world data is messy.
#
# **Common Problems:**
# - ❌ Missing Values
# - ❌ Duplicate Records
# - ❌ Wrong Entries
# - ❌ Outliers
# - ❌ Inconsistent Formats
#
# **Example:**
# ```
# Name     Age
# Aman     20
# Riya         ← Missing age!
# Aman     20  ← Duplicate!
# ```
#
# **Cleaning Activities:**
# - ✔ Remove duplicates
# - ✔ Fill missing values
# - ✔ Correct data types
# - ✔ Standardize formats
# - ✔ Handle outliers
#
# > 📌 **Rule: Data Scientists spend nearly 70–80% of their time cleaning data.**

# %% [markdown]
# ## 4️⃣ Data Analysis (EDA)
#
# **EDA = Exploratory Data Analysis**
#
# Goal: Understand the data **before** building models.
#
# **Questions to Answer:**
# - What patterns exist?
# - What trends are visible?
# - Which variables are important?
# - Are there relationships between features?
#
# **Techniques:**
# - ✔ Mean, Median, Mode
# - ✔ Correlation
# - ✔ Distribution Analysis
# - ✔ Trend Analysis
#
# **Role: Data Analyst + Data Scientist**

# %% [markdown]
# ## 5️⃣ Data Visualization
#
# > *"Humans understand pictures better than tables."*
#
# **Common Charts:**
# 1. Bar Chart
# 2. Line Chart
# 3. Pie Chart
# 4. Histogram
# 5. Scatter Plot
# 6. Heatmap
#
# **Tools:**
# - Matplotlib, Seaborn, Plotly (Python)
# - Tableau, Power BI (Business)
#
# **Output:** Dashboards, Reports, Business Insights

# %% [markdown]
# ## 6️⃣ Model Building (Introduction)
#
# This is where **Machine Learning begins**!
#
# Goal: Use historical data to make **predictions**.
#
# **Real-World Examples:**
# - Netflix → Predicts movies you may like
# - Amazon → Predicts products you may buy
# - Bank   → Predicts loan default risk
#
# **Types of ML Models:**
# | Type | Task | Example |
# |------|------|---------|
# | Regression | Predict numbers | House price |
# | Classification | Predict categories | Spam / Not Spam |
# | Clustering | Group similar data | Customer Segmentation |

# %% [markdown]
# ## 7️⃣ Model Evaluation
#
# We must test whether the model performs well.
#
# **Metrics:**
# - ✔ Accuracy
# - ✔ Precision
# - ✔ Recall
# - ✔ F1 Score
# - ✔ RMSE
#
# **Example:**
# If a model predicts customer churn with **92% accuracy** → it is considered effective ✅
#
# ## 8️⃣ Deployment
#
# After testing, the model is deployed for real users.
#
# ```
# Role  : Machine Learning Engineer
# Tools : Flask, FastAPI, Docker, AWS, Azure
# Output: Live AI System 🚀
# ```
#
# ## 9️⃣ Monitoring & Improvement
#
# Models become outdated over time. Customer behavior changes. New data arrives daily.
#
# ```
# ✔ Monitor performance
# ✔ Retrain model
# ✔ Improve accuracy
# ✔ Update data
#
# Example: Google Maps continuously updates traffic predictions.
# ```
