# %% [markdown]
# # Day-05: Functions & File Handling
# ## Functions
#
# A **function** is a reusable block of code that performs a specific task.
# Functions help organize code, reduce repetition, and make programs easier to understand and maintain.
#
# - Advantages of Functions
# - Code Reusability: Write once and use multiple times.
# - Reduces Code Duplication: Avoids writing the same code repeatedly.
# - Improves Readability: Programs become easier to understand.
# - Easy Maintenance: Changes need to be made in only one place.
# - Better Testing & Debugging: Functions can be tested independently.
# - Modular Programming: Large programs can be divided into smaller modules.

# %%
# intro 

# def Greet(n) :
#     print(f"\n Kya haaal {n} !")
Greet(input("Enter name :"))

#  Lamda function  , anonmous function
# Greet = lambda n :  print(f"\n Kya haaal {n} !")
# Out:
# Enter name : adi
#  Kya haaal adi !

# %%
# positional argumenet
add = lambda a,b : a-b
print(add(b=10 , a=200))
# Out:
# 190

# %%
# defaiult value 
# def f(a,c,b="Hello"):
#     print(a, b, c)
f("A", "C")
# Out:
# A Hello C

# %%
# Variable length Argumenets (*args , **kwargs)
def add(*n):
    # print(sum())
    print(n)
add(1,1,1,1,1,1,1,1,1)
# add((1,1,1,1,1,1,1,1,1))
# Out:
# (1, 1, 1, 1, 1, 1, 1, 1, 1, 'H')

# %%
def student(**n):
    print(n)
student(name="adi", age =24)
# Out:
# {'name': 'adi', 'age': 24}

# %% [markdown]
# # Types of Functions
# ## functions mainly two types :
#  1. Built- in Functions :
#     - len()
#     - type()
#     - max() , min()
#     - sum()
#     - round()
#     - abs()
#  2. User-Defined functions
#     - Normal Function (def)
#     - Anonymous Functions (lambda)
#     - Recursive Function
#     - Generator Function

# %%
#  Lamda function  , anonmous function
# a = lambda n :  print(f"\n Kya haaal {n} !")
a(input("Enter name :"))
# Out:
# Enter name : adi
#  Kya haaal adi !

# %%
# funcrinons for additiona
# add = lambda *n : sum(n)
sub = lambda n1,n2 : n1 - n2
def cal(a,b):
  print("Addition :",add(a,b))
  print("Subtraction :",sub(a,b))
   
a, b =map(int,input("ENter two numbers with space seperated :").split(" "))
cal(a,b)
# Out:
# ENter two numbers with space seperated : 10 12
# Addition : 22
# Subtraction : -2

# %%
# greet = lambda : f"Hello World"
# print(type(greet()))
c = lambda n : n*n*n
print(c(2))
# Out:
# 8

# %% [markdown]
# # Recursive Function

# %%
# Create a fucntion for calculator

add = lambda n1, n2 : n1 + n2
sub = lambda n1,n2 : n1 - n2
mul = lambda n1,n2 : n1 * n2
div = lambda n1,n2 : n1 // n2
rem = lambda n1,n2 : n1 % n2

# a, b =map(int,input("ENter two numbers with comma(,) seperated :").split(","))

def calculator():
    a, b =map(int,input("ENter two numbers with comma(,) seperated :").split(","))
    ch = input("Enter ch or symobol to calculate (+,-,*,/,%) \n if u want to end =0 ")
    if ch == "0":
        return "COME AGAIN !"
    match ch:
        case "+":
            print("Addition :",add(a,b))
        case "-":
            print("Subtraction :",sub(a,b))
        case "*":
            print("Multiplication :",mul(a,b))
        case "/":
            print("Division :",div(a,b))
        case "%":
            print("Remainder :",rem(a,b))
        case _:
            print("ERROR:INVALID NUMBER")
    calculator(a,b)
calculator(a,b)

# %% [markdown]
# - infinite recursive function is runs until the stack memorey fulls

# %%
# Sum of numbers from 1 to n using recursion
def sum_to_n(n):
    if n == 0:
        return 0
    return n+ sum_to_n(n-1)
   
print(sum_to_n(10))
# Out:
# 55

# %%
# Sum of digits of a number using recursion 
def sum_of_digits(n):
    if n == 0:
        return 0
    return n%10 + sum_of_digits(n//10)

print(sum_of_digits(123))
# Out:
# 6

# %%
# Factorial of a number using recursion
def factorial(n):
    if n == 1:
        return 1
    return n * factorial(n-1)
print(factorial(5))
# Out:
# 120

# %%
# Generator Function

def count_up_to(n):
    count = 1
    while count <= n:
        yield count
        count += 1
print("Counting up to 5:", tuple(count_up_to(5)))
# Out:
# Counting up to 5: (1, 2, 3, 4, 5)

# %% [markdown]
# # Scientific calculator

# %%
import math

# Functions
add = lambda a, b: a + b
sub = lambda a, b: a - b
mul = lambda a, b: a * b
div = lambda a, b: a / b
power = lambda a, b: a ** b
square = lambda a: a * a
cube = lambda a: a * a * a
sqrt = lambda a: math.sqrt(a)
factorial = lambda a: math.factorial(int(a))
mod = lambda a, b: a % b
sin = lambda a: math.sin(math.radians(a))
cos = lambda a: math.cos(math.radians(a))
tan = lambda a: math.tan(math.radians(a))
log = lambda a: math.log10(a)
ln = lambda a: math.log(a)
ceil = lambda a: math.ceil(a)
floor = lambda a: math.floor(a)
absolute = lambda a: abs(a)
maximum = lambda a, b: max(a, b)
minimum = lambda a, b: min(a, b)

while True:
    print("SCIENTIFIC CALCULATOR","1.Add 2.Subtract 3.Multiply 4.Divide 5.Power 6.Square 7.Cube 8.Square Root 9.Factorial 10.Modulus 11.Sin 12.Cos 13.Tan 14.Log 15.Natural Log 16.Ceil 17.Floor 18.Absolute 19.Maximum 20.Minimum 0.CLose",sep="\n")

    ch = int(input("Enter ch: "))

    if ch ==0:
        print("CLOSE")
        break
    if ch in [1,2,3,4,5,10,19,20]:
        a = float(input("Enter First Number: "))
        b = float(input("Enter Second Number: "))
    
    if ch in [6,7,8,9,11,12,13,14,15,16,17,18]:
        a = float(input("Enter Number: "))
    
    if ch == 1:
        print(add(a,b))
    elif ch == 2:
        print(sub(a,b))
    elif ch == 3:
        print(mul(a,b))
    elif ch == 4:
        print(div(a,b))
    elif ch == 5:
        print(power(a,b))
    elif ch == 6:
        print(square(a))
    elif ch == 7:
        print(cube(a))
    elif ch == 8:
        print(sqrt(a))
    elif ch == 9:
        print(factorial(int(a)))
    elif ch == 10:
        print(mod(a,b))
    elif ch == 11:
        print(sin(a))
    elif ch == 12:
        print(cos(a))
    elif ch == 13:
        print(tan(a))
    elif ch == 14:
        print(log(a))
    elif ch == 15:
        print(ln(a))
    elif ch == 16:
        print(ceil(a))
    elif ch == 17:
        print(floor(a))
    elif ch == 18:
        print(absolute(a))
    elif ch == 19:
        print(maximum(a,b))
    elif ch == 20:
        print(minimum(a,b))
    else:
        print("Invalid ch")
# Out:
# SCIENTIFIC CALCULATOR
# 1.Add 2.Subtract 3.Multiply 4.Divide 5.Power 6.Square 7.Cube 8.Square Root 9.Factorial 10.Modulus 11.Sin 12.Cos 13.Tan 14.Log 15.Natural Log 16.Ceil 17.Floor 18.Absolute 19.Maximum 20.Minimum 0.CLose

# %% [markdown]
# # File Handling
