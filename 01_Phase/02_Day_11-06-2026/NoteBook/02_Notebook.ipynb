# %% [markdown]
# # Day 2: Python Data Types, Operators, Decision Control Statements

# %% [markdown]
# ## 1. Python Data Types
# Practice questions to explore data types.

# %% [markdown]
# ### Question 1: Employee Information System
# Write a Python program to create the following variables:
# * Employee ID (`int`)
# * Salary (`float`)
# * Employee Name (`str`)
# * Permanent Employee Status (`bool`)
#
# Print:
# * Value of each variable
# * Data type using `type()`
# * Memory address using `id()`

# %%
# Write your solution for Question 1 here

# %% [markdown]
# ### Question 2: Student Data Collection
# Write a Python program to store:
# * A list of 5 subjects
# * A tuple of 5 marks
# * A set of 5 hobbies
# * A dictionary containing student details (`name`, `age`, `city`)
#
# Print:
# * Values of all variables
# * Their data types
# * Their memory addresses

# %%
# Write your solution for Question 2 here

# %% [markdown]
# ### Question 3: Complete Data Type Explorer
# Write a Python program that creates at least one variable of each of the following data types:
# * `int`, `float`, `complex`, `str`, `bool`, `list`, `tuple`, `range`, `set`, `frozenset`, `dict`, `None`
#
# For each variable, print:
# * Value
# * Data Type (`type()`)
# * Memory Address (`id()`)
# * Documentation (`__doc__`)
# * Print the total number of methods `len(dir(variable))`

# %%
# Write your solution for Question 3 here

# %% [markdown]
# ## 2. Python Operators
# Practice questions for Operators.

# %% [markdown]
# ### Question 1: Predict the Output (Operator Precedence)
# Without running the code, predict the output:
# ```python
# 10 + 5 * 2
# (10 + 5) * 2
# 20 // 3
# 20 % 3
# 2 ** 4
# 10 + 5 * 2 ** 2
# (10 + 5) * 2 ** 2
# 100 // 3 + 5
# 50 - 10 * 2 + 5
# 2 ** 3 ** 2
# (2 ** 3) ** 2
# ```

# %%
# Verify your predictions here

# %% [markdown]
# ### Question 2: Predict the Output (Logical, Comparison & Membership)
# Without executing the code, predict the output:
# ```python
# 5 > 3 and 10 < 20
# 5 > 10 or 20 > 15
# not(10 == 10)
# 10 + 5 > 12
# 15 == 15 and 20 != 10
# 'a' in 'apple'
# 'z' not in 'python'
# 10 == 10
# 10 != 20
# 15 >= 10
# 5 <= 2
# True and False or True
# not(False)
# ```

# %%
# Verify your predictions here

# %% [markdown]
# ### Question 3: Predict the Output (Bitwise, Identity & Mixed)
# Without running the code, predict the output:
# ```python
# 5 & 3
# 5 | 3
# 5 ^ 3
# 10 >> 1
# 5 << 2
#
# a = [1, 2, 3]
# b = a
# c = [1, 2, 3]
#
# a is b
# a is c
# a == c
#
# 5 | 3 & 2
# 10 ^ 5 & 3
# 10 + 20 > 25 and 5 * 2 == 10
# 100 // 3 > 30 or 5 < 2
# not(10 > 5 and 20 < 30)
# ```

# %%
# Verify your predictions here

# %% [markdown]
# ## 3. Conditional Statements
# Practice questions for decision making.

# %% [markdown]
# ### Question 1: Restaurant Menu Program using if elif else
# Create a menu-driven Python program for a restaurant.
# ```text
# ==============================
#      RESTAURANT MENU
# ==============================
# 1. Pizza
# 2. Burger
# 3. Sandwich
# 4. Exit
# ```
# Ask the user to enter their choice.
# * Display the selected food item.
# * If the user selects `4`, display a thank-you message.
# * If the user enters an invalid choice, display an appropriate error message.

# %%
# Write your solution for Question 1 here

# %% [markdown]
# ### Question 2: Movie Ticket Booking System using match
# Create a menu-driven Python program for a movie theater.
# ```text
# ==============================
#       MOVIE MENU
# ==============================
# 1. Pushpa 3
# 2. Jawan 2
# 3. Kalki 2
# 4. Exit
# ```
# Ask the user to enter their choice.
# * Display the selected movie name.
# * If the user selects `4`, display a thank-you message.
# * If the user enters an invalid choice, display an appropriate error message.

# %%
# Write your solution for Question 2 here

# %% [markdown]
# ## 🚀 Day-02 Project
# ### University Management System
# Create a complete program that produces this output:
# ```text
# ==================================================
#       UNIVERSITY MANAGEMENT SYSTEM
# ==================================================
# Enter Student Name : asif
# Enter Roll Number  : 123
#
# ===== MENU =====
# 1. Result Calculator
# 2. Attendance Checker
# 3. Scholarship Checker
#
# Enter Your Choice : 1
#
# ===== RESULT CALCULATOR =====
# Enter Python Marks  : 78
# Enter Maths Marks   : 56
# Enter English Marks : 76
#
# ==================================================
#               RESULT CARD
# ==================================================
# Student Name : asif
# Roll Number  : 123
# Total Marks  : 210.0
# Percentage   : 70.0
# Grade        : B
# Result       : Pass
#
# ==================================================
#         THANK YOU FOR USING UMS
# ==================================================
# ```

# %%
# Build the University Management System Project here
