# %% [markdown]
# # Day-04 Project 4 CLS
#
#  ====================================
#       COLLEGE LIBRARY SYSTEM
#  ====================================
#
# Library Name : Arya College Library
# Location     : Jaipur
#
# Available Books:
# 1. Python Programming
# 2. Data Structures
# 3. DBMS
# 4. Computer Networks
# 5. Operating System
#
# Book Categories:
# Programming
# Database
# Networking
# System
#
# Book Stock:
# Python Programming : 10
# Data Structures    : 8
# DBMS               : 6
# Computer Networks  : 5
# Operating System   : 4
#
# Checking Book Availability...
#
# Enter Book Name : Python Programming
#
# Book Available in Library
#
# Total Books Titles : 5
# Total Categories   : 4

# %%
l_name ="Arya College Library"
location = "Jaipur"

b_stock = {
    "Python Programming": 10,
    "Data Structures": 8,
    "DBMS": 6,
    "Computer Networks": 5,
    "Operating System": 4
}
categories = [
    "Programming",
    "Database",
    "Networking",
    "System"
]

print("="*10, "College Library System","="*10, sep="\n")
